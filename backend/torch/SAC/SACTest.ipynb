# %% [markdown]
# # Training

# %%
import itertools
import datetime
import sys
sys.path.insert(0,'../../envs/')
sys.path.insert(0,'../core/')

import os
from utils import *
from global_vars import BATCH_SIZE, DT, SEED
from PegRobot2D import Frontend, WINDOW_X, WINDOW_Y
import numpy as np
import torch
from sac import SAC
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt
from rl_batch_trainer import BatchRLAlgorithm

variant = dict(
        algorithm="SAC",
        version="normal",
        seed = 1,
        save_model = True,

        algorithm_kwargs=dict(
            num_epochs= 25,
            num_eval_steps_per_epoch= 1000,
            num_train_loops_per_epoch = 10,
            num_trains_per_train_loop= 250, 
            num_expl_steps_per_train_loop = 1000,
            min_num_steps_before_training = 10000,
            max_path_length= 250,
            batch_size = 256,
            prioritised_experience = True,
            importance_sampling = True,
        ),

        trainer_kwargs=dict(
            gamma=0.99,
            tau=0.005,
            target_update_interval=1,
            lr= 5e-4, # Was 5e-3
            alpha = 0.2,
            policy = "Gaussian",
            automatic_entropy_tuning=True,
            hidden_size = 64,       
            delayed_policy_steps = 2,
            replay_buffer_size = int(2e5),
        ),

        env_args = [
            WINDOW_X,
            WINDOW_Y,
            "Peg 2D Robot"
            ],

        env_kwargs = dict(
            vsync = False,
            resizable = False,
            visible = False
            )
)

# Environment
env = Frontend(*variant['env_args'], **variant['env_kwargs'])
if variant['algorithm'] is "SAC":
    env.denorm_process = False # No need to denorm because in SAC the gaussian policies are already scaled up
elif variant['algorithm'] is "DDPG" or "TD3":
    env.denorm_process = True # Action outputs are in [-1, 1] so we need to denormalise them to pass into the envirnoment

torch.manual_seed(variant['seed'])
np.random.seed(variant['seed'])

# Agent
num_actions = env.num_actions
num_inputs = env.num_states
action_range = env.action_range

agent = SAC(num_inputs, num_actions, action_range, **variant['trainer_kwargs'])

# Tensorboard
log_dir = 'runs/{}_SAC_{}_{}_{}'.format(datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S"),
                                        "Peg2DRobot",
                                        variant['trainer_kwargs']['policy'],
                                       "autotune" if variant['trainer_kwargs']['automatic_entropy_tuning'] else "")
writer = SummaryWriter(logdir=log_dir)

# training
RL_trainer = BatchRLAlgorithm(**variant['algorithm_kwargs']) 
RL_trainer.train(env, agent, writer)

# Save model 
if variant['save_model']:
    agent.save_model("Peg2D")
# Out:
# Loading chipmunk for Windows (64bit) [C:\Users\Alvaro\Anaconda3\lib\site-packages\pymunk\chipmunk.dll]
# Working on CPU, GPU is too old
# Target Entropy -3
# Initial Exploration ...
# Finished Initial Exploration on 10000 steps
#
# Finished Epoch 0, replay size 20000
# Finished Epoch 1, replay size 30000
# Finished Epoch 2, replay size 40000
#
#  MADE IT 1 TIMES TO GOAL
#
#
#  MADE IT 2 TIMES TO GOAL
#
#
#  MADE IT 3 TIMES TO GOAL
#
# Finished Epoch 3, replay size 50000
#
#  MADE IT 4 TIMES TO GOAL
#
#
#  MADE IT 5 TIMES TO GOAL
#
#
#  MADE IT 6 TIMES TO GOAL
#
#
#  MADE IT 7 TIMES TO GOAL
#
# Finished Epoch 4, replay size 60000
#
#  MADE IT 8 TIMES TO GOAL
#
#
#  MADE IT 9 TIMES TO GOAL
#
#
#  MADE IT 10 TIMES TO GOAL
#
#
#  MADE IT 11 TIMES TO GOAL
#
# Finished Epoch 5, replay size 70000
#
#  MADE IT 12 TIMES TO GOAL
#
#
#  MADE IT 13 TIMES TO GOAL
#
#
#  MADE IT 14 TIMES TO GOAL
#
#
#  MADE IT 15 TIMES TO GOAL
#
#
#  MADE IT 16 TIMES TO GOAL
#
#
#  MADE IT 17 TIMES TO GOAL
#
#
#  MADE IT 18 TIMES TO GOAL
#
#
#  MADE IT 19 TIMES TO GOAL
#
#
#  MADE IT 20 TIMES TO GOAL
#
#
#  MADE IT 21 TIMES TO GOAL
#
#
#  MADE IT 22 TIMES TO GOAL
#
#
#  MADE IT 23 TIMES TO GOAL
#
#
#  MADE IT 24 TIMES TO GOAL
#
#
#  MADE IT 25 TIMES TO GOAL
#
#
#  MADE IT 26 TIMES TO GOAL
#
#
#  MADE IT 27 TIMES TO GOAL
#
#
#  MADE IT 28 TIMES TO GOAL
#
#
#  MADE IT 29 TIMES TO GOAL
#
#
#  MADE IT 30 TIMES TO GOAL
#
#
#  MADE IT 31 TIMES TO GOAL
#
#
#  MADE IT 32 TIMES TO GOAL
#
# Finished Epoch 6, replay size 80000
#
#  MADE IT 33 TIMES TO GOAL
#
#
#  MADE IT 34 TIMES TO GOAL
#
#
#  MADE IT 35 TIMES TO GOAL
#
#
#  MADE IT 36 TIMES TO GOAL
#
#
#  MADE IT 37 TIMES TO GOAL
#
#
#  MADE IT 38 TIMES TO GOAL
#
#
#  MADE IT 39 TIMES TO GOAL
#
#
#  MADE IT 40 TIMES TO GOAL
#
#
#  MADE IT 41 TIMES TO GOAL
#
#
#  MADE IT 42 TIMES TO GOAL
#
#
#  MADE IT 43 TIMES TO GOAL
#
#
#  MADE IT 44 TIMES TO GOAL
#
#
#  MADE IT 45 TIMES TO GOAL
#
#
#  MADE IT 46 TIMES TO GOAL
#
#
#  MADE IT 47 TIMES TO GOAL
#
#
#  MADE IT 48 TIMES TO GOAL
#
#
#  MADE IT 49 TIMES TO GOAL
#
# Finished Epoch 7, replay size 90000
#
#  MADE IT 50 TIMES TO GOAL
#
#
#  MADE IT 51 TIMES TO GOAL
#
#
#  MADE IT 52 TIMES TO GOAL
#
#
#  MADE IT 53 TIMES TO GOAL
#
#
#  MADE IT 54 TIMES TO GOAL
#
#
#  MADE IT 55 TIMES TO GOAL
#
#
#  MADE IT 56 TIMES TO GOAL
#
#
#  MADE IT 57 TIMES TO GOAL
#
#
#  MADE IT 58 TIMES TO GOAL
#
#
#  MADE IT 59 TIMES TO GOAL
#
#
#  MADE IT 60 TIMES TO GOAL
#
#
#  MADE IT 61 TIMES TO GOAL
#
#
#  MADE IT 62 TIMES TO GOAL
#
#
#  MADE IT 63 TIMES TO GOAL
#
#
#  MADE IT 64 TIMES TO GOAL
#
#
#  MADE IT 65 TIMES TO GOAL
#
#
#  MADE IT 66 TIMES TO GOAL
#
#
#  MADE IT 67 TIMES TO GOAL
#
#
#  MADE IT 68 TIMES TO GOAL
#
#
#  MADE IT 69 TIMES TO GOAL
#
#
#  MADE IT 70 TIMES TO GOAL
#
#
#  MADE IT 71 TIMES TO GOAL
#
#
#  MADE IT 72 TIMES TO GOAL
#
#
#  MADE IT 73 TIMES TO GOAL
#
#
#  MADE IT 74 TIMES TO GOAL
#
#
#  MADE IT 75 TIMES TO GOAL
#
#
#  MADE IT 76 TIMES TO GOAL
#
# Finished Epoch 8, replay size 100000
#
#  MADE IT 77 TIMES TO GOAL
#
#
#  MADE IT 78 TIMES TO GOAL
#
#
#  MADE IT 79 TIMES TO GOAL
#
#
#  MADE IT 80 TIMES TO GOAL
#
#
#  MADE IT 81 TIMES TO GOAL
#
#
#  MADE IT 82 TIMES TO GOAL
#
#
#  MADE IT 83 TIMES TO GOAL
#
#
#  MADE IT 84 TIMES TO GOAL
#
#
#  MADE IT 85 TIMES TO GOAL
#
#
#  MADE IT 86 TIMES TO GOAL
#
#
#  MADE IT 87 TIMES TO GOAL
#
#
#  MADE IT 88 TIMES TO GOAL
#
#
#  MADE IT 89 TIMES TO GOAL
#
#
#  MADE IT 90 TIMES TO GOAL
#
#
#  MADE IT 91 TIMES TO GOAL
#
#
#  MADE IT 92 TIMES TO GOAL
#
#
#  MADE IT 93 TIMES TO GOAL
#
#
#  MADE IT 94 TIMES TO GOAL
#
#
#  MADE IT 95 TIMES TO GOAL
#
#
#  MADE IT 96 TIMES TO GOAL
#
#
#  MADE IT 97 TIMES TO GOAL
#
# Finished Epoch 9, replay size 110000
#
#  MADE IT 98 TIMES TO GOAL
#
#
#  MADE IT 99 TIMES TO GOAL
#
#
#  MADE IT 100 TIMES TO GOAL
#
#
#  MADE IT 101 TIMES TO GOAL
#
#
#  MADE IT 102 TIMES TO GOAL
#
#
#  MADE IT 103 TIMES TO GOAL
#
#
#  MADE IT 104 TIMES TO GOAL
#
#
#  MADE IT 105 TIMES TO GOAL
#
#
#  MADE IT 106 TIMES TO GOAL
#
#
#  MADE IT 107 TIMES TO GOAL
#
#
#  MADE IT 108 TIMES TO GOAL
#
#
#  MADE IT 109 TIMES TO GOAL
#
#
#  MADE IT 110 TIMES TO GOAL
#
#
#  MADE IT 111 TIMES TO GOAL
#
#
#  MADE IT 112 TIMES TO GOAL
#
#
#  MADE IT 113 TIMES TO GOAL
#
#
#  MADE IT 114 TIMES TO GOAL
#
#
#  MADE IT 115 TIMES TO GOAL
#
#
#  MADE IT 116 TIMES TO GOAL
#
#
#  MADE IT 117 TIMES TO GOAL
#
#
#  MADE IT 118 TIMES TO GOAL
#
#
#  MADE IT 119 TIMES TO GOAL
#
#
#  MADE IT 120 TIMES TO GOAL
#
#
#  MADE IT 121 TIMES TO GOAL
#
#
#  MADE IT 122 TIMES TO GOAL
#
# Finished Epoch 10, replay size 120000
#
#  MADE IT 123 TIMES TO GOAL
#
#
#  MADE IT 124 TIMES TO GOAL
#
#
#  MADE IT 125 TIMES TO GOAL
#
#
#  MADE IT 126 TIMES TO GOAL
#
#
#  MADE IT 127 TIMES TO GOAL
#
#
#  MADE IT 128 TIMES TO GOAL
#
#
#  MADE IT 129 TIMES TO GOAL
#
#
#  MADE IT 130 TIMES TO GOAL
#
#
#  MADE IT 131 TIMES TO GOAL
#
#
#  MADE IT 132 TIMES TO GOAL
#
#
#  MADE IT 133 TIMES TO GOAL
#
#
#  MADE IT 134 TIMES TO GOAL
#
#
#  MADE IT 135 TIMES TO GOAL
#
#
#  MADE IT 136 TIMES TO GOAL
#
#
#  MADE IT 137 TIMES TO GOAL
#
#
#  MADE IT 138 TIMES TO GOAL
#
#
#  MADE IT 139 TIMES TO GOAL
#
#
#  MADE IT 140 TIMES TO GOAL
#
#
#  MADE IT 141 TIMES TO GOAL
#
#
#  MADE IT 142 TIMES TO GOAL
#
#
#  MADE IT 143 TIMES TO GOAL
#
#
#  MADE IT 144 TIMES TO GOAL
#
#
#  MADE IT 145 TIMES TO GOAL
#
#
#  MADE IT 146 TIMES TO GOAL
#
#
#  MADE IT 147 TIMES TO GOAL
#
#
#  MADE IT 148 TIMES TO GOAL
#
#
#  MADE IT 149 TIMES TO GOAL
#
#
#  MADE IT 150 TIMES TO GOAL
#
#
#  MADE IT 151 TIMES TO GOAL
#
# Finished Epoch 11, replay size 130000
#
#  MADE IT 152 TIMES TO GOAL
#
#
#  MADE IT 153 TIMES TO GOAL
#
#
#  MADE IT 154 TIMES TO GOAL
#
#
#  MADE IT 155 TIMES TO GOAL
#
#
#  MADE IT 156 TIMES TO GOAL
#
#
#  MADE IT 157 TIMES TO GOAL
#
#
#  MADE IT 158 TIMES TO GOAL
#
#
#  MADE IT 159 TIMES TO GOAL
#
#
#  MADE IT 160 TIMES TO GOAL
#
#
#  MADE IT 161 TIMES TO GOAL
#
#
#  MADE IT 162 TIMES TO GOAL
#
#
#  MADE IT 163 TIMES TO GOAL
#
#
#  MADE IT 164 TIMES TO GOAL
#
#
#  MADE IT 165 TIMES TO GOAL
#
#
#  MADE IT 166 TIMES TO GOAL
#
# Finished Epoch 12, replay size 140000
#
#  MADE IT 167 TIMES TO GOAL
#
#
#  MADE IT 168 TIMES TO GOAL
#
#
#  MADE IT 169 TIMES TO GOAL
#
#
#  MADE IT 170 TIMES TO GOAL
#
#
#  MADE IT 171 TIMES TO GOAL
#
#
#  MADE IT 172 TIMES TO GOAL
#
#
#  MADE IT 173 TIMES TO GOAL
#
#
#  MADE IT 174 TIMES TO GOAL
#
#
#  MADE IT 175 TIMES TO GOAL
#
#
#  MADE IT 176 TIMES TO GOAL
#
#
#  MADE IT 177 TIMES TO GOAL
#
#
#  MADE IT 178 TIMES TO GOAL
#
#
#  MADE IT 179 TIMES TO GOAL
#
#
#  MADE IT 180 TIMES TO GOAL
#
#
#  MADE IT 181 TIMES TO GOAL
#
#
#  MADE IT 182 TIMES TO GOAL
#
#
#  MADE IT 183 TIMES TO GOAL
#
#
#  MADE IT 184 TIMES TO GOAL
#
#
#  MADE IT 185 TIMES TO GOAL
#
#
#  MADE IT 186 TIMES TO GOAL
#
# Finished Epoch 13, replay size 150000
#
#  MADE IT 187 TIMES TO GOAL
#
#
#  MADE IT 188 TIMES TO GOAL
#
#
#  MADE IT 189 TIMES TO GOAL
#
#
#  MADE IT 190 TIMES TO GOAL
#
#
#  MADE IT 191 TIMES TO GOAL
#
#
#  MADE IT 192 TIMES TO GOAL
#
#
#  MADE IT 193 TIMES TO GOAL
#
#
#  MADE IT 194 TIMES TO GOAL
#
#
#  MADE IT 195 TIMES TO GOAL
#
#
#  MADE IT 196 TIMES TO GOAL
#
#
#  MADE IT 197 TIMES TO GOAL
#
#
#  MADE IT 198 TIMES TO GOAL
#
#
#  MADE IT 199 TIMES TO GOAL
#
# Finished Epoch 14, replay size 160000
#
#  MADE IT 200 TIMES TO GOAL
#
#
#  MADE IT 201 TIMES TO GOAL
#
#
#  MADE IT 202 TIMES TO GOAL
#
#
#  MADE IT 203 TIMES TO GOAL
#
#
#  MADE IT 204 TIMES TO GOAL
#
#
#  MADE IT 205 TIMES TO GOAL
#
#
#  MADE IT 206 TIMES TO GOAL
#
#
#  MADE IT 207 TIMES TO GOAL
#
#
#  MADE IT 208 TIMES TO GOAL
#
#
#  MADE IT 209 TIMES TO GOAL
#
#
#  MADE IT 210 TIMES TO GOAL
#
#
#  MADE IT 211 TIMES TO GOAL
#
#
#  MADE IT 212 TIMES TO GOAL
#
#
#  MADE IT 213 TIMES TO GOAL
#
#
#  MADE IT 214 TIMES TO GOAL
#
# Finished Epoch 15, replay size 170000
#
#  MADE IT 215 TIMES TO GOAL
#
#
#  MADE IT 216 TIMES TO GOAL
#
#
#  MADE IT 217 TIMES TO GOAL
#
#
#  MADE IT 218 TIMES TO GOAL
#
#
#  MADE IT 219 TIMES TO GOAL
#
#
#  MADE IT 220 TIMES TO GOAL
#
#
#  MADE IT 221 TIMES TO GOAL
#
# Finished Epoch 16, replay size 180000
#
#  MADE IT 222 TIMES TO GOAL
#
#
#  MADE IT 223 TIMES TO GOAL
#
#
#  MADE IT 224 TIMES TO GOAL
#
#
#  MADE IT 225 TIMES TO GOAL
#
#
#  MADE IT 226 TIMES TO GOAL
#
#
#  MADE IT 227 TIMES TO GOAL
#
#
#  MADE IT 228 TIMES TO GOAL
#
#
#  MADE IT 229 TIMES TO GOAL
#
#
#  MADE IT 230 TIMES TO GOAL
#
#
#  MADE IT 231 TIMES TO GOAL
#
#
#  MADE IT 232 TIMES TO GOAL
#
# Finished Epoch 17, replay size 190000
#
#  MADE IT 233 TIMES TO GOAL
#
#
#  MADE IT 234 TIMES TO GOAL
#
#
#  MADE IT 235 TIMES TO GOAL
#
#
#  MADE IT 236 TIMES TO GOAL
#
#
#  MADE IT 237 TIMES TO GOAL
#
#
#  MADE IT 238 TIMES TO GOAL
#
#
#  MADE IT 239 TIMES TO GOAL
#
#
#  MADE IT 240 TIMES TO GOAL
#
#
#  MADE IT 241 TIMES TO GOAL
#
#
#  MADE IT 242 TIMES TO GOAL
#
#
#  MADE IT 243 TIMES TO GOAL
#
#
#  MADE IT 244 TIMES TO GOAL
#
#
#  MADE IT 245 TIMES TO GOAL
#
#
#  MADE IT 246 TIMES TO GOAL
#
#
#  MADE IT 247 TIMES TO GOAL
#
#
#  MADE IT 248 TIMES TO GOAL
# Finished Epoch 18, replay size 200000
#
#  MADE IT 249 TIMES TO GOAL
#
#
#  MADE IT 250 TIMES TO GOAL
#
#
#  MADE IT 251 TIMES TO GOAL
#
#
#  MADE IT 252 TIMES TO GOAL
#
#
#  MADE IT 253 TIMES TO GOAL
#
#
#  MADE IT 254 TIMES TO GOAL
#
#
#  MADE IT 255 TIMES TO GOAL
#
#
#  MADE IT 256 TIMES TO GOAL
#
#
#  MADE IT 257 TIMES TO GOAL
#
#
#  MADE IT 258 TIMES TO GOAL
#
#
#  MADE IT 259 TIMES TO GOAL
#
#
#  MADE IT 260 TIMES TO GOAL
#
#
#  MADE IT 261 TIMES TO GOAL
#
#
#  MADE IT 262 TIMES TO GOAL
#
#
#  MADE IT 263 TIMES TO GOAL
#
#
#  MADE IT 264 TIMES TO GOAL
#
#
#  MADE IT 265 TIMES TO GOAL
#
#
#  MADE IT 266 TIMES TO GOAL
#
#
#  MADE IT 267 TIMES TO GOAL
#
# Finished Epoch 19, replay size 200000
#
#  MADE IT 268 TIMES TO GOAL
#
#
#  MADE IT 269 TIMES TO GOAL
#
#
#  MADE IT 270 TIMES TO GOAL
#
#
#  MADE IT 271 TIMES TO GOAL
#
#
#  MADE IT 272 TIMES TO GOAL
#
#
#  MADE IT 273 TIMES TO GOAL
#
#
#  MADE IT 274 TIMES TO GOAL
#
#
#  MADE IT 275 TIMES TO GOAL
#
#
#  MADE IT 276 TIMES TO GOAL
#
#
#  MADE IT 277 TIMES TO GOAL
#
#
#  MADE IT 278 TIMES TO GOAL
#
#
#  MADE IT 279 TIMES TO GOAL
#
#
#  MADE IT 280 TIMES TO GOAL
#
#
#  MADE IT 281 TIMES TO GOAL
#
#
#  MADE IT 282 TIMES TO GOAL
#
#
#  MADE IT 283 TIMES TO GOAL
#
#
#  MADE IT 284 TIMES TO GOAL
#
#
#  MADE IT 285 TIMES TO GOAL
#
#
#  MADE IT 286 TIMES TO GOAL
#
#
#  MADE IT 287 TIMES TO GOAL
#
#
#  MADE IT 288 TIMES TO GOAL
#
#
#  MADE IT 289 TIMES TO GOAL
#
# Finished Epoch 20, replay size 200000
#
#  MADE IT 290 TIMES TO GOAL
#
#
#  MADE IT 291 TIMES TO GOAL
#
#
#  MADE IT 292 TIMES TO GOAL
#
#
#  MADE IT 293 TIMES TO GOAL
#
#
#  MADE IT 294 TIMES TO GOAL
#
#
#  MADE IT 295 TIMES TO GOAL
#
#
#  MADE IT 296 TIMES TO GOAL
#
#
#  MADE IT 297 TIMES TO GOAL
#
#
#  MADE IT 298 TIMES TO GOAL
#
#
#  MADE IT 299 TIMES TO GOAL
#
#
#  MADE IT 300 TIMES TO GOAL
#
#
#  MADE IT 301 TIMES TO GOAL
#
#
#  MADE IT 302 TIMES TO GOAL
#
#
#  MADE IT 303 TIMES TO GOAL
#
#
#  MADE IT 304 TIMES TO GOAL
#
#
#  MADE IT 305 TIMES TO GOAL
#
#
#  MADE IT 306 TIMES TO GOAL
#
# Finished Epoch 21, replay size 200000
#
#  MADE IT 307 TIMES TO GOAL
#
#
#  MADE IT 308 TIMES TO GOAL
#
#
#  MADE IT 309 TIMES TO GOAL
#
#
#  MADE IT 310 TIMES TO GOAL
#
#
#  MADE IT 311 TIMES TO GOAL
#
#
#  MADE IT 312 TIMES TO GOAL
#
#
#  MADE IT 313 TIMES TO GOAL
#
#
#  MADE IT 314 TIMES TO GOAL
#
#
#  MADE IT 315 TIMES TO GOAL
#
#
#  MADE IT 316 TIMES TO GOAL
#
#
#  MADE IT 317 TIMES TO GOAL
#
#
#  MADE IT 318 TIMES TO GOAL
#
#
#  MADE IT 319 TIMES TO GOAL
#
#
#  MADE IT 320 TIMES TO GOAL
#
#
#  MADE IT 321 TIMES TO GOAL
#
#
#  MADE IT 322 TIMES TO GOAL
#
# Finished Epoch 22, replay size 200000
#
#  MADE IT 323 TIMES TO GOAL
#
#
#  MADE IT 324 TIMES TO GOAL
#
#
#  MADE IT 325 TIMES TO GOAL
#
#
#  MADE IT 326 TIMES TO GOAL
#
#
#  MADE IT 327 TIMES TO GOAL
#
#
#  MADE IT 328 TIMES TO GOAL
#
#
#  MADE IT 329 TIMES TO GOAL
#
#
#  MADE IT 330 TIMES TO GOAL
#
#
#  MADE IT 331 TIMES TO GOAL
#
#
#  MADE IT 332 TIMES TO GOAL
#
#
#  MADE IT 333 TIMES TO GOAL
#
#
#  MADE IT 334 TIMES TO GOAL
#
#
#  MADE IT 335 TIMES TO GOAL
#
#
#  MADE IT 336 TIMES TO GOAL
#
#
#  MADE IT 337 TIMES TO GOAL
#
#
#  MADE IT 338 TIMES TO GOAL
#
#
#  MADE IT 339 TIMES TO GOAL
#
#
#  MADE IT 340 TIMES TO GOAL
#
#
#  MADE IT 341 TIMES TO GOAL
#
#
#  MADE IT 342 TIMES TO GOAL
#
#
#  MADE IT 343 TIMES TO GOAL
#
#
#  MADE IT 344 TIMES TO GOAL
#
#
#  MADE IT 345 TIMES TO GOAL
#
#
#  MADE IT 346 TIMES TO GOAL
#
#
#  MADE IT 347 TIMES TO GOAL
#
#
#  MADE IT 348 TIMES TO GOAL
#
#
#  MADE IT 349 TIMES TO GOAL
#
#
#  MADE IT 350 TIMES TO GOAL
#
#
#  MADE IT 351 TIMES TO GOAL
#
#
#  MADE IT 352 TIMES TO GOAL
#
#
#  MADE IT 353 TIMES TO GOAL
#
#
#  MADE IT 354 TIMES TO GOAL
#
#
#  MADE IT 355 TIMES TO GOAL
#
#
#  MADE IT 356 TIMES TO GOAL
#
#
#  MADE IT 357 TIMES TO GOAL
#
#
#  MADE IT 358 TIMES TO GOAL
#
#
#  MADE IT 359 TIMES TO GOAL
#
#
#  MADE IT 360 TIMES TO GOAL
#
#
#  MADE IT 361 TIMES TO GOAL
#
#
#  MADE IT 362 TIMES TO GOAL
#
#
#  MADE IT 363 TIMES TO GOAL
#
#
#  MADE IT 364 TIMES TO GOAL
#
#
#  MADE IT 365 TIMES TO GOAL
#
# Finished Epoch 23, replay size 200000
#
#  MADE IT 366 TIMES TO GOAL
#
#
#  MADE IT 367 TIMES TO GOAL
#
#
#  MADE IT 368 TIMES TO GOAL
#
#
#  MADE IT 369 TIMES TO GOAL
#
#
#  MADE IT 370 TIMES TO GOAL
#
#
#  MADE IT 371 TIMES TO GOAL
#
#
#  MADE IT 372 TIMES TO GOAL
#
#
#  MADE IT 373 TIMES TO GOAL
#
#
#  MADE IT 374 TIMES TO GOAL
#
#
#  MADE IT 375 TIMES TO GOAL
#
#
#  MADE IT 376 TIMES TO GOAL
#
#
#  MADE IT 377 TIMES TO GOAL
#
#
#  MADE IT 378 TIMES TO GOAL
#
#
#  MADE IT 379 TIMES TO GOAL
#
#
#  MADE IT 380 TIMES TO GOAL
#
#
#  MADE IT 381 TIMES TO GOAL
#
#
#  MADE IT 382 TIMES TO GOAL
#
#
#  MADE IT 383 TIMES TO GOAL
#
#
#  MADE IT 384 TIMES TO GOAL
#
#
#  MADE IT 385 TIMES TO GOAL
#
#
#  MADE IT 386 TIMES TO GOAL
#
#
#  MADE IT 387 TIMES TO GOAL
#
#
#  MADE IT 388 TIMES TO GOAL
#
#
#  MADE IT 389 TIMES TO GOAL
#
#
#  MADE IT 390 TIMES TO GOAL
#
#
#  MADE IT 391 TIMES TO GOAL
#
# Finished Epoch 24, replay size 200000
# Saving models to models/actor_Peg2D_ and models/critic_Peg2D_

# %%
print('\n Trainer ...')
for attribute, value in RL_trainer.__dict__.items():
    print(attribute, '=', value)
print('\n Agent ...')
for attribute, value in agent.__dict__.items():
    print(attribute, '=', value)
# Out:
#  Trainer ...
# batch_size = 128
# max_path_length = 250
# num_epochs = 25
# num_eval_steps_per_epoch = 1000
# num_trains_per_train_loop = 250
# num_train_loops_per_epoch = 10
# num_expl_steps_per_train_loop = 1000
# min_num_steps_before_training = 10000
# path_type = ['random', 'exploration', 'eval']
# memory_steps = 260000
# updates = 62500
# prioritised_experience = True
# importance_sampling = True
#
#  Agent ...
# num_actions = 3
# gamma = 0.99
# tau = 0.005
# alpha = tensor([0.0231], grad_fn=<ExpBackward>)
# delayed_policy_steps = 2
# policy_type = Gaussian
# target_update_interval = 1
# automatic_entropy_tuning = True
# device = cpu
# critic = QNetwork(
#   (linear1): Linear(in_features=7, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=1, bias=True)
#   (linear4): Linear(in_features=7, out_features=64, bias=True)
#   (linear5): Linear(in_features=64, out_features=64, bias=True)
#   (linear6): Linear(in_features=64, out_features=1, bias=True)
# )
# critic_optim = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# critic_target = QNetwork(
#   (linear1): Linear(in_features=7, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (linear3): Linear(in_features=64, out_features=1, bias=True)
#   (linear4): Linear(in_features=7, out_features=64, bias=True)
#   (linear5): Linear(in_features=64, out_features=64, bias=True)
#   (linear6): Linear(in_features=64, out_features=1, bias=True)
# )
# target_entropy = -3
# log_alpha = tensor([-3.7693], requires_grad=True)
# alpha_optim = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# policy = GaussianPolicy(
#   (linear1): Linear(in_features=4, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (mean_linear): Linear(in_features=64, out_features=3, bias=True)
#   (log_std_linear): Linear(in_features=64, out_features=3, bias=True)
# )
# policy_optim = Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0005
#     weight_decay: 0
# )
# replay_buffer = <utils.ReplayBuffer object at 0x0000019CD457C6A0>

# %% [markdown]
# # Testing

# %%
import itertools
import datetime
import sys
sys.path.insert(0,'../../envs/')
sys.path.insert(0,'../core/')

import os
from utils import *
from PegRobot2D import Frontend, WINDOW_X, WINDOW_Y
import numpy as np
import torch
from sac import SAC
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt

variant = dict(
        algorithm="SAC",
        version="normal",
        seed = 1,
        save_model = True,

        algorithm_kwargs=dict(
            num_epochs= 25,
            num_eval_steps_per_epoch= 1000,
            num_train_loops_per_epoch = 10,
            num_trains_per_train_loop= 250, # Was 100
            num_expl_steps_per_train_loop = 1000,
            min_num_steps_before_training = 10000, # Random exploration steps Initially
            max_path_length= 250,
            batch_size = 128,
            prioritised_experience = True,
            importance_sampling = True,
        ),

        trainer_kwargs=dict(
            gamma=0.99,
            tau=0.005,
            target_update_interval=1,
            lr= 5e-4, # Was 5e-3
            alpha = 0.2,
            policy = "Gaussian",
            automatic_entropy_tuning=True,
            hidden_size = 64,       
            delayed_policy_steps = 2,
            replay_buffer_size = int(2e5),
        ),

        env_args = [
            WINDOW_X,
            WINDOW_Y,
            "Peg 2D Robot"
            ],

        env_kwargs = dict(
            vsync = False,
            resizable = False,
            visible = False
            )
)


# Environment
env = Frontend(*variant['env_args'], **variant['env_kwargs'])
if variant['algorithm'] is "SAC":
    env.denorm_process = False # No need to denorm because in SAC the gaussian policies are already scaled up
    
torch.manual_seed(variant['seed'])
np.random.seed(variant['seed'])

def run_policy(agent, env = None, framework = "SAC"):
    if isinstance(env, Frontend):
        del(env)
    env = Frontend(WINDOW_X, WINDOW_Y, "RoboPeg2D Simulation", vsync = False, resizable = False, visible = True)
    env.agent = agent
    if framework is "SAC":
        env.denorm_process = False # Necessary for SAC
    env.run_policy(agent)

if __name__ == "__main__":
    env = Frontend(WINDOW_X, WINDOW_Y, "RoboPeg2D Simulation", vsync = False, resizable = False, visible = False)
    
    # Agent
    num_actions = env.num_actions
    num_inputs = env.num_states
    action_range = env.action_range

    tst_agent = SAC(num_inputs, num_actions, action_range, **variant['trainer_kwargs'])

    tst_agent.load_model(actor_path="models/actor_Peg2D_",critic_path="models/critic_Peg2D_")

    run_policy(tst_agent, env, "SAC")
# Out:
# Loading chipmunk for Windows (64bit) [C:\Users\Alvaro\Anaconda3\lib\site-packages\pymunk\chipmunk.dll]
# Working on CPU, GPU is too old
# Target Entropy -3
# Loading models from models/actor_Peg2D_ and models/critic_Peg2D_
